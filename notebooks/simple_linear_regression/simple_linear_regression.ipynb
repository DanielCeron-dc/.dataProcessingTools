# %% [markdown]
# # Simple Lineal Regression

# %% [markdown]
# ## preprocessing

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import os

path = os.path.join(os.path.abspath(''), 'salary_data.csv')
print(path)
dataset =  pd.read_csv(path)
X = np.array(dataset.iloc[:, :-1])
y = np.array(dataset.iloc[:,-1])

from sklearn.model_selection import train_test_split

X_train , X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state=0)

print("size of x_train", X_train.shape[0])
print("size of x_test", X_test.shape[0])
# Out:
# d:\Documents\Python\.dataProcessingTools\notebooks\simple_linear_regression\salary_data.csv
# size of x_train 24
# size of x_test (6, 1)

# %% [markdown]
# ### Training the simple lineal regression model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()  ## regression is when we have to predict a continuos value
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predicting the test results

# %%
prediction = regressor.predict(X_test)
print(prediction)
# Out:
# [ 40748.96184072 122699.62295594  64961.65717022  63099.14214487
#  115249.56285456 107799.50275317]

# %% [markdown]
# ### Visualising the training set results

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.legend('Salary')
plt.ylabel('Salary')
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Visualising the test set results

# %%
plt.plot(X_test, regressor.predict(X_test), color = 'blue')
plt.scatter(X_test, y_test, color = 'red')
plt.scatter(X_test, regressor.predict(X_test), color = 'green')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
